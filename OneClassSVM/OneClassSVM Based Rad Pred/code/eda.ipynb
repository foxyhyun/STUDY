# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('../data/data.csv')
df.head()
# Out:
#    Unnamed: 0                 time  temp  rain  wind(m/s)  wind_dir  humidity  \
# 0           0  2019-01-01 00:00:00  -4.9   0.0        0.4         0        62
# 1           1  2019-01-01 01:00:00  -4.4   0.0        0.6        90        61
# 2           2  2019-01-01 02:00:00  -3.9   0.0        0.4         0        59
# 3           3  2019-01-01 03:00:00  -4.4   0.0        1.0       200        61
# 4           4  2019-01-01 04:00:00  -5.1   0.0        0.7       320        66
#
#       hPa  snow    mR/h
# 0  1026.9   0.0  0.0105
# 1  1026.7   0.0  0.0106
# 2  1026.7   0.0  0.0106
# 3  1027.2   0.0  0.0106
# 4  1026.7   0.0  0.0105

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8737 entries, 0 to 8736
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  8737 non-null   int64
#  1   time        8737 non-null   object
#  2   temp        8737 non-null   float64
#  3   rain        8737 non-null   float64
#  4   wind(m/s)   8737 non-null   float64
#  5   wind_dir    8737 non-null   int64
#  6   humidity    8737 non-null   int64
#  7   hPa         8737 non-null   float64
#  8   snow        8737 non-null   float64
#  9   mR/h        8737 non-null   float64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 682.7+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# time          0
# temp          0
# rain          0
# wind(m/s)     0
# wind_dir      0
# humidity      0
# hPa           0
# snow          0
# mR/h          0
# dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0         temp         rain    wind(m/s)     wind_dir  \
# count  8737.000000  8737.000000  8737.000000  8737.000000  8737.000000
# mean   4368.000000    14.108859     0.112647     1.325810   172.271947
# std    2522.298984    10.296985     0.814137     1.077166   124.223873
# min       0.000000    -9.400000     0.000000     0.000000     0.000000
# 25%    2184.000000     5.200000     0.000000     0.600000    50.000000
# 50%    4368.000000    15.000000     0.000000     1.100000   200.000000
# 75%    6552.000000    22.900000     0.000000     1.800000   270.000000
# max    8736.000000    35.800000    25.700000    10.600000   360.000000
#
#           humidity          hPa    snow         mR/h
# count  8737.000000  8737.000000  8737.0  8737.000000
# mean     68.514479  1008.450464     0.0     0.010611
# std      20.320397     8.219534     0.0     0.000445
# min       8.000000   982.900000     0.0     0.009800
# 25%      54.000000  1002.200000     0.0     0.010400
# ...

# %%
df.drop(['Unnamed: 0','snow'],axis=1,inplace=True)

# %%
df.corr()
# Out:
# /var/folders/37/brl3s2hn2rdfswx8sdr8xp000000gn/T/ipykernel_10832/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                temp      rain  wind(m/s)  wind_dir  humidity       hPa  \
# temp       1.000000  0.048506   0.188936 -0.173769  0.059091 -0.798145
# rain       0.048506  1.000000   0.020036 -0.003837  0.179072 -0.121905
# wind(m/s)  0.188936  0.020036   1.000000  0.265105 -0.319452 -0.199377
# wind_dir  -0.173769 -0.003837   0.265105  1.000000 -0.280394  0.124262
# humidity   0.059091  0.179072  -0.319452 -0.280394  1.000000 -0.238487
# hPa       -0.798145 -0.121905  -0.199377  0.124262 -0.238487  1.000000
# mR/h       0.043497  0.362680  -0.019035 -0.035844  0.138412 -0.291372
#
#                mR/h
# temp       0.043497
# rain       0.362680
# wind(m/s) -0.019035
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8732    False
# 8733    False
# 8734    False
# 8735    False
# 8736    False
# Length: 8737, dtype: bool

# %%
df.columns
# Out:
# Index(['time', 'temp', 'rain', 'wind(m/s)', 'wind_dir', 'humidity', 'hPa',
#        'mR/h'],
#       dtype='object')

# %%
# 스타일 지정
plt.style.use('dark_background')

plt.boxplot([df['mR/h']])

# 그래프 타이틀과 축 레이블 추가
plt.title('Boxplot of mR/h')
plt.ylabel('mR/h')

# 그래프 출력
plt.show()

# %%
# 스타일 지정
plt.style.use('dark_background')

# x축: 'temp', y축: 'nsv'인 scatterplot 그리기
plt.scatter(df['temp'], df['mR/h'])

# 그래프 타이틀과 축 레이블 추가
plt.title('Scatterplot of temp vs mR/h')
plt.xlabel('temp')
plt.ylabel('mR/h')

# 그래프 출력
plt.show()

# %%
# 스타일 지정
plt.style.use('dark_background')

# x축: 'temp', y축: 'nsv'인 scatterplot 그리기
plt.scatter(df['temp'], df['mR/h'])

# 그래프 타이틀과 축 레이블 추가
plt.title('Scatterplot of temp vs mR/h')
plt.xlabel('rain')
plt.ylabel('mR/h')

# 그래프 출력
plt.show()

# %%
# 스타일 지정
plt.style.use('dark_background')

# x축: 'temp', y축: 'nsv'인 scatterplot 그리기
plt.scatter(df['wind(m/s)'], df['mR/h'])

# 그래프 타이틀과 축 레이블 추가
plt.title('Scatterplot of temp vs mR/h')
plt.xlabel('wind(m/s)')
plt.ylabel('mR/h')

# 그래프 출력
plt.show()

# %%
# 스타일 지정
plt.style.use('dark_background')

# x축: 'temp', y축: 'nsv'인 scatterplot 그리기
plt.scatter(df['humidity'], df['mR/h'])

# 그래프 타이틀과 축 레이블 추가
plt.title('Scatterplot of temp vs mR/h')
plt.xlabel('humidity')
plt.ylabel('mR/h')

# 그래프 출력
plt.show()

# %%
# 스타일 지정
plt.style.use('dark_background')

# x축: 'temp', y축: 'nsv'인 scatterplot 그리기
plt.scatter(df['humidity'], df['hPa'])

# 그래프 타이틀과 축 레이블 추가
plt.title('Scatterplot of temp vs mR/h')
plt.xlabel('hPa')
plt.ylabel('mR/h')

# 그래프 출력
plt.show()

# %%
# 스타일 지정
plt.style.use('dark_background')

# 상관계수 행렬 그리기
sns.heatmap(df.corr(), cmap='coolwarm', annot=True, square=True)

# 그래프 출력
plt.show()
# Out:
# /var/folders/37/brl3s2hn2rdfswx8sdr8xp000000gn/T/ipykernel_10832/3236077705.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap='coolwarm', annot=True, square=True)
